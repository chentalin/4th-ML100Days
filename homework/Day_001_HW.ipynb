# %% [markdown]
# # 作業一

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    mae= MAE= sum(abs(y-yp))/ len(y)
    return mae
def mean_squared_error(y, yp):
    mse= MSE= sum(abs(y-yp)**2)
    return mse

# %%
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 22570.441
# The Mean absolute error is 12.056

# %% [markdown]
# # 作業二

# %% [markdown]
# # Competitions:
#
# # University of Liverpool – Ion Switching
# # Identify the number of channels open at each time point
# [University of Liverpool - Ion Switching](https://www.kaggle.com/c/liverpool-ion-switching)
# ## 1.你選的這組資料為何重要?
# * 動物體內神經細胞表面的離子通道影響著神經電訊號的傳遞，離子通道開啟的數量影響著訊號的強弱，開啟的時機影響著感覺或生理反應是否發生，這對我們的學習、記憶、對抗疾病感染、痛覺和控制肌肉運動皆息息相關。如果我們能夠更深入研究離子通道的作用機制，對於上述的研究領域皆會有重要的影響。
#
# * 然而神經細胞表面的離子通道非常的微小，不僅電流強度十分微弱，使用一般的電生理實驗方式(利用探針檢測神經細胞軸突旁的電流強度訊號)，會收到許多不相干的雜訊，雖能知道離子通道有開啟，但開啟的通道數量仍難以被掌握，以目前的科技，若科學家想要精準地統計細胞膜上離子通道開啟的數量，必須使用奈米級的玻璃針頭，內含奈米級的金屬絲，在不戳破神經細胞的狀況下剛好罩在神經細胞的離子通道口，才有機會接收到清楚的訊號，實驗過程曠日廢時，而這項技術二十年未曾有顯著的突破。
#
# * 利物浦大學希望能透過機器學習讓電腦可以從充滿雜訊的圖譜中精確的預估出離子通道開啟的數量，進而突破研究上的障礙。
#
# ## 2.資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)?
# * 提供者:University of Liverpool’s institute of Aging and Chronic Disease
#
# * 細胞電生理的實驗方式如問題一的回答所述，利物浦大學同時利用了簡單但會充滿雜訊的方式和費時費工但可以得到精準數據的方式進行實驗，以提供電腦作為學習的參考
#
# ## 3.蒐集而來的資料型態為何?
# * 資料型態有兩種，一般的電生理實驗所得結果為(橫軸)時間、(縱軸)電流強度的圖譜{圖一}，精密實驗所得的結果為(橫軸)時間、(縱軸)離子通道開啟數量的統計圖譜{圖二}
#
# (圖一)![圖一](圖1.png)
# (圖二)![圖二](圖2.png)
#
# ## 4.這組資料想解決的問題如何評估?
# * 每張圖(一般電生理實驗結果)皆有相應的答案(精密實驗結果)，可先隨機抽取80%的資料作為電腦的Training Group，保留20%作為Test Group
#
# * 在訓練完電腦之後，讓它進行預測，看看是否能準確從一般電生理圖譜正確預估出精密實驗的數據。

# %% [markdown]
# # 作業三

# %% [markdown]
# # 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# ## 1.核心問題為何? (tips：如何定義 「提升業績 & 你的假設」)
# * 為何有人會有通勤需求呢?
# * 哪裡會有比較多的通勤需求?
# * 哪個時段會有比較多的通勤需求?
# * 那些人願意使用我的車隊?
# * 如何有效率的滿足上述需求?
#
# ## 2.資料從何而來? (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
# 民眾有載客需求，可分兩種狀況:
#
# ### A.在特定的日期時間，會突然有許多外縣市的旅客湧入，他們或許因為交通不便，或許因為有趕時間的需求，會捨棄大眾交通工具而搭乘計程車、Uber等載客車隊，以下資料皆可以從網路收集:
# * 台鐵、高鐵不同時段的載客量統計
# * 公職考試、大型考試的日期時間地點公告
# * 大型慶典活動時間地點公告
# * 郵輪、離島客輪停泊時間地點公告
#
# ### B.在市內的居民，也有人會因為個人因素而有固定使用載客工具的習慣，這些數據必須藉由
# * 叫車app或是行車定位的時間地點人數統計
#
# ## 3.蒐集而來的資料型態為何?
# * 針對外來客，資料型態大多是日期時間-人數的統計圖
# * 針對市內居民，資料型態是日期時間-地點-人數的統計圖，並能預測有無固定的重複頻率，若使用叫車app還能針對每位用戶的習慣進行分析
#
# ## 4.你要回答的問題，其如何評估? (tips：你的假設如何驗證)
# * 為何有人會有通勤需求呢?
# 我假設在固定時間點，會有許多需要搭乘交通工具的外來旅客湧入，驗證的方法是統計司機的載客紀錄(人數、時間、地點)是否與大型考試、祭典、郵輪停泊、台鐵高鐵載客量起伏的時間週期吻合。
#
# * 哪裡會有比較多的通勤需求?
# 統計火車站、高鐵站、大型慶典和旅遊勝地周邊是否出現較大的載客需求
#
# * 哪個時段會有比較多的通勤需求?
# 統計在有公職、大型考試、大型慶典在本市舉辦時，是否有出現載客量的增加
#
# * 那些人願意使用我的車隊?
# 分析使用app叫車的人的年齡層，針對該課曾的日常生活習慣進行預測之後，統計載客需求是否符合預測
#
# * 如何有效率的滿足上述需求?
# 統籌分配車隊，滿足上述的各項載客需求，並統計收益是否有成長。
